# %%
import sys
import os

# Agrega la ruta al directorio que contiene src
ruta_proyecto = os.path.abspath(os.path.join(".."))
sys.path.append(ruta_proyecto) 
print("Ruta de 'src':", os.path.join(ruta_proyecto, "src"))

from src.funciones import inicializador_de_jugadores, procesador_de_ronda, actualizar_estadisticas, encontrarMVP, print_round_ranking, print_final_ranking

rounds = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]

## Hacemos una esctructura lista que contenga las llaves del diccionario (nombre de los players)
nombres_players = list(rounds[0].keys())

## A una variable le voy a cargar el diccionario inicializado en 0 que retorna la funcion 'inicializador_de_jugadores'
players_data = inicializador_de_jugadores(nombres_players)

## Empiezo a procesar cada ronda y a trabajar con la informacion
for round_num, info_ronda in enumerate(rounds, 1):
    round_points = procesador_de_ronda(info_ronda)
## convoco al modulo que actualiza las estadisticas acumuladas,le paso el diccionario que voy a printiar, estadisticas de la ronda actual, 
## y los puntos calculados para esta ronda
    actualizar_estadisticas (players_data, info_ronda, round_points)
## busco el mvp de la ronda con la siguiente funcion
    mvp = encontrarMVP (round_points)
    players_data[mvp]['mvps'] += 1  ##almaceno en el apartado de 'MVPs' un punto al jugador que fue mvp en la ronda actual
    print_round_ranking(round_num, players_data, mvp) ##muestra el ranking despues de cada ronda
print_final_ranking(players_data)
# Out:
# Ruta de 'src': /home/pcluk/entrega2/src
#
# Ranking ronda 1:
# Jugador   | Kills | Asistencias | Muertes | MVPs | Puntos
# -------------------------------------------------------
# Shadow   |   2   |      1      |    1    |  1   | 6
# Viper    |   1   |      2      |    1    |  0   | 4
# Reaper   |   1   |      1      |    0    |  0   | 4
# Blaze    |   1   |      0      |    0    |  0   | 3
# Frost    |   0   |      1      |    0    |  0   | 1
#
# MVP de la ronda: Shadow
#
# Ranking ronda 2:
# Jugador   | Kills | Asistencias | Muertes | MVPs | Puntos
# -------------------------------------------------------
# Shadow   |   2   |      3      |    1    |  1   | 8
# Blaze    |   3   |      0      |    1    |  0   | 8
# Viper    |   2   |      3      |    1    |  0   | 8
# Frost    |   2   |      2      |    1    |  1   | 7
# Reaper   |   1   |      2      |    0    |  0   | 5
#
# MVP de la ronda: Frost
#
# Ranking ronda 3:
# Jugador   | Kills | Asistencias | Muertes | MVPs | Puntos
# ...
